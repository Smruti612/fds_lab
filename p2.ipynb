# %%
import pandas as pd

# %%
m = pd.read_csv("./files/titanic.csv")

# %%
d1=pd.DataFrame(m)
d1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
n1=d1.fillna(0)
n1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
n2=d1.fillna(method='backfill')
n2
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2184\991938560.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   n2=d1.fillna(method='backfill')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
n3=d1.fillna(method='ffill',axis='columns')
n3
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2184\4087501356.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   n3=d1.fillna(method='ffill',axis='columns')
#     PassengerId Survived Pclass  \
# 0             1        0      3
# 1             2        1      1
# 2             3        1      3
# 3             4        1      1
# 4             5        0      3
# ..          ...      ...    ...
# 886         887        0      2
# 887         888        1      1
# 888         889        0      3
# 889         890        1      1
# 890         891        0      3
#
#                                                   Name     Sex     Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male    22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    38.0     1
# 2                               Heikkinen, Miss. Laina  female    26.0     0
# ...

# %%
n4=d1.interpolate()
n4
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2184\1963930798.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   n4=d1.interpolate()
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
n5=d1.dropna()
n5
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=pd.date_range('1-1-17','30-1-17')
idx=pd.DatetimeIndex(x)
n6=d1.reindex(idx)
n6
# Out:
#             PassengerId  Survived  Pclass Name  Sex  Age  SibSp  Parch Ticket  \
# 2017-01-01          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-02          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-03          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-04          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-05          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-06          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-07          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-08          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-09          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-10          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# 2017-01-11          NaN       NaN     NaN  NaN  NaN  NaN    NaN    NaN    NaN
# ...

# %%
n7=d1.replace(0,'NaN')
n7
# Out:
#      PassengerId Survived  Pclass  \
# 0              1      NaN       3
# 1              2        1       1
# 2              3        1       3
# 3              4        1       1
# 4              5      NaN       3
# ..           ...      ...     ...
# 886          887      NaN       2
# 887          888        1       1
# 888          889      NaN       3
# 889          890        1       1
# 890          891      NaN       3
#
#                                                   Name     Sex   Age SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0     1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0     1
# 2                               Heikkinen, Miss. Laina  female  26.0   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0     1
# 4                             Allen, Mr. William Henry    male  35.0   NaN
# ..                                                 ...     ...   ...   ...
# ...

# %%
n8=d1.replace('[A-Za-z]','.',regex=True) #here a to z expression are replaced with -100000 or dot
n8
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              ......, ... .... ......    ....  22.0      1
# 1    ......., .... .... ....... (........ ...... .....  ......  38.0      1
# 2                               ........., ..... .....  ......  26.0      0
# 3         ........, .... ....... ..... (.... ... ....)  ......  35.0      1
# 4                             ....., ... ....... .....    ....  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
d2=pd.DataFrame({
    'score':['good','very good','ok','average','poor','very poor'],
    'name':['rhea','priya','anuj','meena','tom','ravi']
    })
d2
# Out:
#        score   name
# 0       good   rhea
# 1  very good  priya
# 2         ok   anuj
# 3    average  meena
# 4       poor    tom
# 5  very poor   ravi

# %%
n9=d2.replace(['good','very good','ok','average','poor','very poor'],[4.5,5,3,2.5,1,0])
n9
# Out:
#    score   name
# 0    4.5   rhea
# 1    5.0  priya
# 2    3.0   anuj
# 3    2.5  meena
# 4    1.0    tom
# 5    0.0   ravi
