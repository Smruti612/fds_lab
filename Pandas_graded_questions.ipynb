# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("./files/MegaMart_sales.csv")

df.shape
# Out:
# (59, 8)

# %% [markdown]
# #### Combining two data frames
# Question 1: Some of the orders are stored in another csv file named `megamart_new sales`. Read the csv file, store it in a data frame and add it to the `megamart_sales` data frame. Find the total sales value of the category 'Office Supplies'  after combining the dataframes
#
#     a)7970
#     b)6964
#     c)7494
#     d)6076

# %%
f1=pd.read_csv("./files/MegaMart_newsales.csv")
d2=pd.DataFrame(f1)

# %%
df=pd.concat([df,d2])
df
# Out:
#            Order ID                                  Product Name  Discount  \
# 0   AZ-2011-1029887    Novimex Color Coded Labels, 5000 Label Set       0.0
# 1    AZ-2011-107716                Deflect-O Door Stop, Erganomic       0.0
# 2   AZ-2011-1087704                 Belkin Flash Drive, Bluetooth       0.0
# 3   AZ-2011-1372644                    Panasonic Printer, Durable       0.0
# 4   AZ-2011-1362199                     Sanford Pens, Fluorescent       0.5
# ..              ...                                           ...       ...
# 4   AZ-2011-1967754                  Logitech Numeric Keypad, USB       0.0
# 5   AZ-2011-1976919                          Boston Markers, Blue       0.0
# 6   AZ-2011-2001312                  Avery Binding Machine, Clear       0.0
# 7   AZ-2011-2002251     SanDisk Computer Printout Paper, 8.5 x 11       0.0
# 8    AZ-2011-201891  Cameo Clasp Envelope, with clear poly window       0.0
#
#     Sales  Profit  Quantity         Category Sub-Category
# 0      26       7         2  Office Supplies       Labels
# 1      85      15         2        Furniture  Furnishings
# 2     294     109         7       Technology  Accessories
# 3     800     168         3       Technology     Machines
# 4      25     -11         4  Office Supplies          Art
# ..    ...     ...       ...              ...          ...
# 4      93      40         2       Technology  Accessories
# 5     132      54         5  Office Supplies          Art
# 6      97      12         2  Office Supplies      Binders
# 7     136      15         4  Office Supplies        Paper
# 8      52      19         4  Office Supplies    Envelopes
#
# [68 rows x 8 columns]

# %%
#Total sales value of category office supplies
ans=df[df['Category']=="Office Supplies"]
ans['Sales'].sum()
# Out:
# 7970

# %%
#your code here
df=pd.concat([df,df_new],axis=0,ignore_index=True)
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\c_programming\mudir\fds\Pandas_graded_questions.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/d%3A/c_programming/mudir/fds/Pandas_graded_questions.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> #your code here
# ----> <a href='vscode-notebook-cell:/d%3A/c_programming/mudir/fds/Pandas_graded_questions.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df=pd.concat([df,df_new],axis=0,ignore_index=True)
#       <a href='vscode-notebook-cell:/d%3A/c_programming/mudir/fds/Pandas_graded_questions.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df.shape
#
# NameError: name 'df_new' is not defined

# %% [markdown]
# #### Dropping duplicates
# Question 2: There are some duplicate rows in the data frame. Drop these rows and calculate the total sales value of the category Office Supplies.
#
#     a)7156
#     b)6496
#     c)6964
#     d)6023

# %% [markdown]
#  Dataframe.duplicated() method of Pandas.
#
#
# Syntax : DataFrame.duplicated(subset = None, keep = ‘first’)
# Parameters:
# subset: This Takes a column or list of column label. It’s default value is None. After passing columns, it will consider them only for duplicates.
# keep: This Controls how to consider duplicate value. It has only three distinct value and default is ‘first’.
#
#
# If ‘first’, This considers first value as unique and rest of the same values as duplicate.
# If ‘last’, This considers last value as unique and rest of the same values as duplicate.
# If ‘False’, This considers all of the same values as duplicates.
# Returns: Boolean Series denoting duplicate rows.

# %% [markdown]
# #### Dropping duplicates
# Question 2: There are some duplicate rows in the data frame. Drop these rows and calculate the total sales value of the category Office Supplies.
#
#     a)7156
#     b)6496
#     c)6964
#     d)6023

# %%
df1=df[df.duplicated()]
df1
# Out:
#            Order ID                                Product Name  Discount  \
# 13  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 25  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
# 28  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 29  AZ-2011-1406494                Fellowes Lockers, Industrial       0.1
# 49  AZ-2011-1499597                 Boston Markers, Fluorescent       0.0
# 54  AZ-2011-1474073  Wilson Jones Hole Reinforcements, Recycled       0.0
# 55  AZ-2011-1645475               BIC Highlighters, Fluorescent       0.5
#
#     Sales  Profit  Quantity         Category Sub-Category
# 13    294     109         7       Technology  Accessories
# 25     25     -11         4  Office Supplies          Art
# 28    800     168         3       Technology     Machines
# 29    748     283         4  Office Supplies      Storage
# 49    193      29         7  Office Supplies          Art
# 54     10       2         2  Office Supplies      Binders
# 55     30     -10         3  Office Supplies          Art

# %%
ans=df1[df1['Category']=="Office Supplies"]
ans['Sales'].sum()
# Out:
# 1006

# %%
#your code here
duplicate = df[df.duplicated()]
duplicate
# Out:
#            Order ID                                Product Name  Discount  \
# 13  AZ-2011-1087704               Belkin Flash Drive, Bluetooth       0.0
# 25  AZ-2011-1362199                   Sanford Pens, Fluorescent       0.5
# 28  AZ-2011-1372644                  Panasonic Printer, Durable       0.0
# 29  AZ-2011-1406494                Fellowes Lockers, Industrial       0.1
# 49  AZ-2011-1499597                 Boston Markers, Fluorescent       0.0
# 54  AZ-2011-1474073  Wilson Jones Hole Reinforcements, Recycled       0.0
# 55  AZ-2011-1645475               BIC Highlighters, Fluorescent       0.5
#
#     Sales  Profit  Quantity         Category Sub-Category
# 13    294     109         7       Technology  Accessories
# 25     25     -11         4  Office Supplies          Art
# 28    800     168         3       Technology     Machines
# 29    748     283         4  Office Supplies      Storage
# 49    193      29         7  Office Supplies          Art
# 54     10       2         2  Office Supplies      Binders
# 55     30     -10         3  Office Supplies          Art

# %% [markdown]
# df.drop_duplicates()
# DataFrame.drop_duplicates(subset=None, *, keep='first', inplace=False, ignore_index=False)[source]
# Return DataFrame with duplicate rows removed.
#
# Considering certain columns is optional. Indexes, including time indexes are ignored.
#
# Parameters
# subsetcolumn label or sequence of labels, optional
# Only consider certain columns for identifying duplicates, by default use all of the columns.
#
# keep{‘first’, ‘last’, False}, default ‘first’
# Determines which duplicates (if any) to keep.
#
# ‘first’ : Drop duplicates except for the first occurrence.
#
# ‘last’ : Drop duplicates except for the last occurrence.
#
# False : Drop all duplicates.
#
# inplacebool, default False
# Whether to modify the DataFrame rather than creating a new one.
#
# ignore_indexbool, default False
# If True, the resulting axis will be labeled 0, 1, …, n - 1.
#
# Returns
# DataFrame or None
# DataFrame with duplicates removed or None if inplace=True.

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (61, 8)

# %%
df.groupby(['Category']).Sales.sum()
# Out:
# Category
# Furniture          2460
# Office Supplies    6964
# Technology         7494
# Name: Sales, dtype: int64

# %% [markdown]
# #### Best category-sub category
# Question 3: Find the most profitable category and sub category combination based on the net profit.
#
#
#     a)Furniture-Bookcases
#     b)Office supplies-Appliances
#     c)Office supplies-Storage
#     d)Technology-Phones

# %%
df
# Out:
#            Order ID                                  Product Name  Discount  \
# 0   AZ-2011-1029887    Novimex Color Coded Labels, 5000 Label Set       0.0
# 1    AZ-2011-107716                Deflect-O Door Stop, Erganomic       0.0
# 2   AZ-2011-1087704                 Belkin Flash Drive, Bluetooth       0.0
# 3   AZ-2011-1372644                    Panasonic Printer, Durable       0.0
# 4   AZ-2011-1362199                     Sanford Pens, Fluorescent       0.5
# ..              ...                                           ...       ...
# 4   AZ-2011-1967754                  Logitech Numeric Keypad, USB       0.0
# 5   AZ-2011-1976919                          Boston Markers, Blue       0.0
# 6   AZ-2011-2001312                  Avery Binding Machine, Clear       0.0
# 7   AZ-2011-2002251     SanDisk Computer Printout Paper, 8.5 x 11       0.0
# 8    AZ-2011-201891  Cameo Clasp Envelope, with clear poly window       0.0
#
#     Sales  Profit  Quantity         Category Sub-Category
# 0      26       7         2  Office Supplies       Labels
# 1      85      15         2        Furniture  Furnishings
# 2     294     109         7       Technology  Accessories
# 3     800     168         3       Technology     Machines
# 4      25     -11         4  Office Supplies          Art
# ..    ...     ...       ...              ...          ...
# 4      93      40         2       Technology  Accessories
# 5     132      54         5  Office Supplies          Art
# 6      97      12         2  Office Supplies      Binders
# 7     136      15         4  Office Supplies        Paper
# 8      52      19         4  Office Supplies    Envelopes
#
# [68 rows x 8 columns]

# %%
df.groupby(['Category','Sub-Category'])['Profit'].max()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       156
#                  Chairs           99
#                  Furnishings      34
# Office Supplies  Appliances      185
#                  Art             132
#                  Binders         102
#                  Envelopes        19
#                  Fasteners        10
#                  Labels            8
#                  Paper            15
#                  Storage         283
#                  Supplies         65
# Technology       Accessories     109
#                  Copiers           0
#                  Machines        168
#                  Phones          820
# Name: Profit, dtype: int64

# %%
#your code here

df.groupby(['Category','Sub-Category'])['Profit'].max()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       156
#                  Chairs           99
#                  Furnishings      34
# Office Supplies  Appliances      185
#                  Art             132
#                  Binders         102
#                  Envelopes        19
#                  Fasteners        10
#                  Labels            8
#                  Paper            15
#                  Storage         283
#                  Supplies         65
# Technology       Accessories     109
#                  Copiers           0
#                  Machines        168
#                  Phones          820
# Name: Profit, dtype: int64

# %%
df
# Out:
#            Order ID                                  Product Name  Discount  \
# 0   AZ-2011-1029887    Novimex Color Coded Labels, 5000 Label Set       0.0
# 1    AZ-2011-107716                Deflect-O Door Stop, Erganomic       0.0
# 2   AZ-2011-1087704                 Belkin Flash Drive, Bluetooth       0.0
# 3   AZ-2011-1372644                    Panasonic Printer, Durable       0.0
# 4   AZ-2011-1362199                     Sanford Pens, Fluorescent       0.5
# ..              ...                                           ...       ...
# 4   AZ-2011-1967754                  Logitech Numeric Keypad, USB       0.0
# 5   AZ-2011-1976919                          Boston Markers, Blue       0.0
# 6   AZ-2011-2001312                  Avery Binding Machine, Clear       0.0
# 7   AZ-2011-2002251     SanDisk Computer Printout Paper, 8.5 x 11       0.0
# 8    AZ-2011-201891  Cameo Clasp Envelope, with clear poly window       0.0
#
#     Sales  Profit  Quantity         Category Sub-Category
# 0      26       7         2  Office Supplies       Labels
# 1      85      15         2        Furniture  Furnishings
# 2     294     109         7       Technology  Accessories
# 3     800     168         3       Technology     Machines
# 4      25     -11         4  Office Supplies          Art
# ..    ...     ...       ...              ...          ...
# 4      93      40         2       Technology  Accessories
# 5     132      54         5  Office Supplies          Art
# 6      97      12         2  Office Supplies      Binders
# 7     136      15         4  Office Supplies        Paper
# 8      52      19         4  Office Supplies    Envelopes
#
# [68 rows x 8 columns]

# %% [markdown]
# #### Invalid order IDs
# Question 4: How many invalid order IDs are there in the data frame? An order id is of the form AZ-2011-Y where Y represents a whole number. A Order ID is said to be valid only if Y consists of 7 digits. Find the number of invalid order IDs in the data frame.
#
#     a)6
#     b)7
#     c)8
#     d)9

# %%
#your code here
pattern=r'AZ-2011-\d{7}'
ans=df['Order ID'].str.contains(pattern)
a=ans.count()
a
# Out:
# 68

# %% [markdown]
# #### Occurence of furniture in top 25 sales
# Question 5: Find the top 25 orders based on sales value and find the number of orders which belong to furniture category.
#
#     a)2
#     b)3
#     c)4
#     d)5

# %%
df3=df.sort_values(by='Sales',ascending=False)
df3=df3.iloc[:25,]
df3
# Out:
#            Order ID                         Product Name  Discount  Sales  \
# 30  AZ-2011-1410648         Nokia Smart Phone, Full Size       0.0   1908
# 58   AZ-2011-176674                Hoover Microwave, Red       0.1   1667
# 8   AZ-2011-1174243     Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840     Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644           Panasonic Printer, Durable       0.0    800
# 28  AZ-2011-1372644           Panasonic Printer, Durable       0.0    800
# 18  AZ-2011-1406494         Fellowes Lockers, Industrial       0.1    748
# 29  AZ-2011-1406494         Fellowes Lockers, Industrial       0.1    748
# 39  AZ-2011-1536006      Logitech Keyboard, Programmable       0.0    666
# 33  AZ-2011-1445262          Apple Smart Phone, Cordless       0.0    636
# 31   AZ-2011-144325        Bush Stackable Bookrack, Pine       0.0    630
# 14  AZ-2011-1260928        Eldon File Cart, Single Width       0.1    576
# 12  AZ-2011-1253407       Safco Stackable Bookrack, Pine       0.1    541
# 48  AZ-2011-1672552      Binney & Smith Sketch Pad, Blue       0.0    510
# 41  AZ-2011-1584049                   Brother Ink, Laser       0.0    442
# 52  AZ-2011-1722024               Cisco Audio Dock, VoIP       0.0    364
# 0   AZ-2011-1902971  Wilson Jones Binding Machine, Clear       0.0    339
# 17   AZ-2011-130330     Office Star Chairmat, Adjustable       0.1    307
# 13  AZ-2011-1087704        Belkin Flash Drive, Bluetooth       0.0    294
# 2   AZ-2011-1087704        Belkin Flash Drive, Bluetooth       0.0    294
# 1   AZ-2011-1916360        Dania 3-Shelf Cabinet, Mobile       0.0    288
# 11  AZ-2011-1240916           Boston Canvas, Water Color       0.0    284
# 34   AZ-2011-145488         Rogers File Cart, Industrial       0.4    255
# 6   AZ-2011-1116129       Avery Binding Machine, Durable       0.0    252
# 42  AZ-2011-1584987          Tenex File Cart, Industrial       0.1    241
#
#     Profit  Quantity         Category Sub-Category
# 30     820         3       Technology       Phones
# 58     185         6  Office Supplies   Appliances
# 8      200         8       Technology       Phones
# 20     316        12       Technology       Phones
# 3      168         3       Technology     Machines
# 28     168         3       Technology     Machines
# 18     283         4  Office Supplies      Storage
# 29     283         4  Office Supplies      Storage
# 39      66         9       Technology  Accessories
# 33     140         1       Technology       Phones
# 31     132         5        Furniture    Bookcases
# 14      51         5  Office Supplies      Storage
# 12     156         4        Furniture    Bookcases
# 48     132        11  Office Supplies          Art
# 41       0         3       Technology      Copiers
# 52     142         2       Technology       Phones
# 0      102         7  Office Supplies      Binders
# 17      99         5        Furniture       Chairs
# 13     109         7       Technology  Accessories
# 2      109         7       Technology  Accessories
# 1       20         2        Furniture    Bookcases
# 11      43         5  Office Supplies          Art
# 34     -98         3  Office Supplies      Storage
# 6       15         5  Office Supplies      Binders
# 42      24         2  Office Supplies      Storage

# %%
# Out:
# Order ID        11
# Product Name    11
# Discount        11
# Sales           11
# Profit          11
# Quantity        11
# Category        11
# Sub-Category    11
# dtype: int64

# %%
#your code here
df2=df.sort_values(by='Sales', ascending=False)
df2=df2.iloc[:25,]
df2
# Out:
#            Order ID                         Product Name  Discount  Sales  \
# 30  AZ-2011-1410648         Nokia Smart Phone, Full Size       0.0   1908
# 58   AZ-2011-176674                Hoover Microwave, Red       0.1   1667
# 8   AZ-2011-1174243     Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840     Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644           Panasonic Printer, Durable       0.0    800
# 18  AZ-2011-1406494         Fellowes Lockers, Industrial       0.1    748
# 39  AZ-2011-1536006      Logitech Keyboard, Programmable       0.0    666
# 33  AZ-2011-1445262          Apple Smart Phone, Cordless       0.0    636
# 31   AZ-2011-144325        Bush Stackable Bookrack, Pine       0.0    630
# 14  AZ-2011-1260928        Eldon File Cart, Single Width       0.1    576
# 12  AZ-2011-1253407       Safco Stackable Bookrack, Pine       0.1    541
# 48  AZ-2011-1672552      Binney & Smith Sketch Pad, Blue       0.0    510
# 41  AZ-2011-1584049                   Brother Ink, Laser       0.0    442
# 52  AZ-2011-1722024               Cisco Audio Dock, VoIP       0.0    364
# 59  AZ-2011-1902971  Wilson Jones Binding Machine, Clear       0.0    339
# 17   AZ-2011-130330     Office Star Chairmat, Adjustable       0.1    307
# 2   AZ-2011-1087704        Belkin Flash Drive, Bluetooth       0.0    294
# 60  AZ-2011-1916360        Dania 3-Shelf Cabinet, Mobile       0.0    288
# 11  AZ-2011-1240916           Boston Canvas, Water Color       0.0    284
# 34   AZ-2011-145488         Rogers File Cart, Industrial       0.4    255
# 6   AZ-2011-1116129       Avery Binding Machine, Durable       0.0    252
# 42  AZ-2011-1584987          Tenex File Cart, Industrial       0.1    241
# 38  AZ-2011-1499597          Boston Markers, Fluorescent       0.0    193
# 46  AZ-2011-1655349           Fiskars Trimmer, Easy Grip       0.0    176
# 43  AZ-2011-1589827     Novimex Steel Folding Chair, Red       0.6    164
#
#     Profit  Quantity         Category Sub-Category
# 30     820         3       Technology       Phones
# 58     185         6  Office Supplies   Appliances
# 8      200         8       Technology       Phones
# 20     316        12       Technology       Phones
# 3      168         3       Technology     Machines
# 18     283         4  Office Supplies      Storage
# 39      66         9       Technology  Accessories
# 33     140         1       Technology       Phones
# 31     132         5        Furniture    Bookcases
# 14      51         5  Office Supplies      Storage
# 12     156         4        Furniture    Bookcases
# 48     132        11  Office Supplies          Art
# 41       0         3       Technology      Copiers
# 52     142         2       Technology       Phones
# 59     102         7  Office Supplies      Binders
# 17      99         5        Furniture       Chairs
# 2      109         7       Technology  Accessories
# 60      20         2        Furniture    Bookcases
# 11      43         5  Office Supplies          Art
# 34     -98         3  Office Supplies      Storage
# 6       15         5  Office Supplies      Binders
# 42      24         2  Office Supplies      Storage
# 38      29         7  Office Supplies          Art
# 46      65         4  Office Supplies     Supplies
# 43     -70         5        Furniture       Chairs

# %%
df2.groupby(['Category']).count()
# Out:
#                  Order ID  Product Name  Discount  Sales  Profit  Quantity  \
# Category
# Furniture               5             5         5      5       5         5
# Office Supplies        11            11        11     11      11        11
# Technology              9             9         9      9       9         9
#
#                  Sub-Category
# Category
# Furniture                   5
# Office Supplies            11
# Technology                  9

# %%
df2['Category'].value_counts()
# Out:
# Office Supplies    11
# Technology          9
# Furniture           5
# Name: Category, dtype: int64

# %%
ans=df3['Category'].value_counts()
ans
# Out:
# Category
# Technology         11
# Office Supplies    10
# Furniture           4
# Name: count, dtype: int64

# %% [markdown]
# #### And operation
# Question 6: Among the orders with sales>250 and profit>50, find the product name of the fourth highest order based on sales value.
#
#     a)Motorola Headset, with Caller ID
#     b)Panasonic Printer, Durable
#     c)Hoover Microwave, Red
#     d)Fellowes Lockers, Industrial

# %%
ans=(df['Sales'] > 250) & (df['Profit'] >50)
y=df[ans]
# Out:
#            Order ID                         Product Name  Discount  Sales  \
# 2   AZ-2011-1087704        Belkin Flash Drive, Bluetooth       0.0    294
# 3   AZ-2011-1372644           Panasonic Printer, Durable       0.0    800
# 8   AZ-2011-1174243     Nokia Audio Dock, with Caller ID       0.0   1334
# 12  AZ-2011-1253407       Safco Stackable Bookrack, Pine       0.1    541
# 13  AZ-2011-1087704        Belkin Flash Drive, Bluetooth       0.0    294
# 14  AZ-2011-1260928        Eldon File Cart, Single Width       0.1    576
# 17   AZ-2011-130330     Office Star Chairmat, Adjustable       0.1    307
# 18  AZ-2011-1406494         Fellowes Lockers, Industrial       0.1    748
# 20  AZ-2011-1322840     Motorola Headset, with Caller ID       0.0    957
# 28  AZ-2011-1372644           Panasonic Printer, Durable       0.0    800
# 29  AZ-2011-1406494         Fellowes Lockers, Industrial       0.1    748
# 30  AZ-2011-1410648         Nokia Smart Phone, Full Size       0.0   1908
# 31   AZ-2011-144325        Bush Stackable Bookrack, Pine       0.0    630
# 33  AZ-2011-1445262          Apple Smart Phone, Cordless       0.0    636
# 39  AZ-2011-1536006      Logitech Keyboard, Programmable       0.0    666
# 48  AZ-2011-1672552      Binney & Smith Sketch Pad, Blue       0.0    510
# 52  AZ-2011-1722024               Cisco Audio Dock, VoIP       0.0    364
# 58   AZ-2011-176674                Hoover Microwave, Red       0.1   1667
# 0   AZ-2011-1902971  Wilson Jones Binding Machine, Clear       0.0    339
#
#     Profit  Quantity         Category Sub-Category
# 2      109         7       Technology  Accessories
# 3      168         3       Technology     Machines
# 8      200         8       Technology       Phones
# 12     156         4        Furniture    Bookcases
# 13     109         7       Technology  Accessories
# 14      51         5  Office Supplies      Storage
# 17      99         5        Furniture       Chairs
# 18     283         4  Office Supplies      Storage
# 20     316        12       Technology       Phones
# 28     168         3       Technology     Machines
# 29     283         4  Office Supplies      Storage
# 30     820         3       Technology       Phones
# 31     132         5        Furniture    Bookcases
# 33     140         1       Technology       Phones
# 39      66         9       Technology  Accessories
# 48     132        11  Office Supplies          Art
# 52     142         2       Technology       Phones
# 58     185         6  Office Supplies   Appliances
# 0      102         7  Office Supplies      Binders

# %%
y=y.sort_values(by='Sales',ascending=False)
y.head(4)
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
# 58   AZ-2011-176674             Hoover Microwave, Red       0.1   1667
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
#
#     Profit  Quantity         Category Sub-Category
# 30     820         3       Technology       Phones
# 58     185         6  Office Supplies   Appliances
# 8      200         8       Technology       Phones
# 20     316        12       Technology       Phones

# %%
#your code here
df3=df.loc[(df['Sales']>250) & (df['Profit']>50)]
df3=df3.sort_values(by='Sales', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[51], line 4
#       2 df3=df.loc[(df['Sales']>250) & (df['Profit']>50)]
#       3 df3=df3.sort_values(by='Sales', ascending=False)
# ----> 4 df3['Product Name'].iloc[4,:]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:869, in _LocationIndexer._validate_tuple_indexer(self, key)
#     864 @final
#     865 def _validate_tuple_indexer(self, key: tuple) -> tuple:
#     866     """
#     867     Check the key for valid keys across my indexer.
#     868     """
# --> 869     key = self._validate_key_length(key)
#     870     key = self._expand_ellipsis(key)
#     871     for i, k in enumerate(key):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:908, in _LocationIndexer._validate_key_length(self, key)
#     906             raise IndexingError(_one_ellipsis_message)
#     907         return self._validate_key_length(key)
# --> 908     raise IndexingError("Too many indexers")
#     909 return key
#
# IndexingError: Too many indexers

# %%
df3.iloc[4,:]
# Out:
# Order ID                   AZ-2011-1372644
# Product Name    Panasonic Printer, Durable
# Discount                               0.0
# Sales                                  800
# Profit                                 168
# Quantity                                 3
# Category                        Technology
# Sub-Category                      Machines
# Name: 3, dtype: object

# %% [markdown]
# #### Column manipulation
# Question 7: Remove the orders with negative profit by dropping the corresponding rows with negative `Profit`. Find the product that makes the lowest profit per Quantity in the Technology category.
#
#     a) Nokia Audio Dock, with Caller ID
#     b) Logitech Keyboard, Programmable
#     c) Motorola Headset, with Caller ID
#     d) Belkin Flash Drive, Bluetooth

# %%
ans=(df['Profit'] < 0)
df[ans].index
df=df.drop(df[ans].index)

# %%
df
# Out:
#            Order ID                                       Product Name  \
# 0   AZ-2011-1029887         Novimex Color Coded Labels, 5000 Label Set
# 1    AZ-2011-107716                     Deflect-O Door Stop, Erganomic
# 2   AZ-2011-1087704                      Belkin Flash Drive, Bluetooth
# 3   AZ-2011-1372644                         Panasonic Printer, Durable
# 5   AZ-2011-1114253                         Tenex Stacking Tray, Black
# 6   AZ-2011-1116129                     Avery Binding Machine, Durable
# 7   AZ-2011-1137571                  Stiletto Letter Opener, Easy Grip
# 8   AZ-2011-1174243                   Nokia Audio Dock, with Caller ID
# 9    AZ-2011-122598               Avery Removable Labels, Alphabetical
# 10  AZ-2011-1229073                         Deflect-O Door Stop, Black
# 11  AZ-2011-1240916                         Boston Canvas, Water Color
# 12  AZ-2011-1253407                     Safco Stackable Bookrack, Pine
# 13  AZ-2011-1087704                      Belkin Flash Drive, Bluetooth
# 14  AZ-2011-1260928                      Eldon File Cart, Single Width
# 15  AZ-2011-1278696                                 Acco Binder, Clear
# 16  AZ-2011-1279238                       Kleencut Scissors, Easy Grip
# 17   AZ-2011-130330                   Office Star Chairmat, Adjustable
# 18  AZ-2011-1406494                       Fellowes Lockers, Industrial
# 19  AZ-2011-1315772                            Breville Toaster, Black
# 20  AZ-2011-1322840                   Motorola Headset, with Caller ID
# 22  AZ-2011-1331897                       Avery Binder Covers, Economy
# 23  AZ-2011-1332474                         OIC Thumb Tacks, Bulk Pack
# 26  AZ-2011-1362591                            Tenex Light Bulb, Black
# 27  AZ-2011-1366554                           Avery Index Tab, Durable
# 28  AZ-2011-1372644                         Panasonic Printer, Durable
# 29  AZ-2011-1406494                       Fellowes Lockers, Industrial
# 30  AZ-2011-1410648                       Nokia Smart Phone, Full Size
# 31   AZ-2011-144325                      Bush Stackable Bookrack, Pine
# 32  AZ-2011-1445249                           Boston Pens, Fluorescent
# 33  AZ-2011-1445262                        Apple Smart Phone, Cordless
# 35  AZ-2011-1474073         Wilson Jones Hole Reinforcements, Recycled
# 36  AZ-2011-1475254   Harbour Creations Color Coded Labels, Adjustable
# 37  AZ-2011-1484679                 Binney & Smith Markers, Easy-Erase
# 38  AZ-2011-1499597                        Boston Markers, Fluorescent
# 39  AZ-2011-1536006                    Logitech Keyboard, Programmable
# 41  AZ-2011-1584049                                 Brother Ink, Laser
# 42  AZ-2011-1584987                        Tenex File Cart, Industrial
# 46  AZ-2011-1655349                         Fiskars Trimmer, Easy Grip
# 47  AZ-2011-1661180                      Jiffy Peel and Seal, Recycled
# 48  AZ-2011-1672552                    Binney & Smith Sketch Pad, Blue
# 49  AZ-2011-1499597                        Boston Markers, Fluorescent
# 50  AZ-2011-1680940                 Smead Round Labels, 5000 Label Set
# 51  AZ-2011-1693949  Harbour Creations Color Coded Labels, Laser Pr...
# 52  AZ-2011-1722024                             Cisco Audio Dock, VoIP
# 53  AZ-2011-1723003                             Ibico Index Tab, Clear
# 54  AZ-2011-1474073         Wilson Jones Hole Reinforcements, Recycled
# 56  AZ-2011-1735855                       Deflect-O Photo Frame, Black
# 57  AZ-2011-1754604                     Avery Binding Machine, Economy
# 58   AZ-2011-176674                              Hoover Microwave, Red
# 0   AZ-2011-1902971                Wilson Jones Binding Machine, Clear
# 1   AZ-2011-1916360                      Dania 3-Shelf Cabinet, Mobile
# 2   AZ-2011-1916555                        Eldon Folders, Single Width
# 3   AZ-2011-1930058                        Sanford Markers, Easy-Erase
# 5   AZ-2011-1976919                               Boston Markers, Blue
# 6   AZ-2011-2001312                       Avery Binding Machine, Clear
# 7   AZ-2011-2002251          SanDisk Computer Printout Paper, 8.5 x 11
# 8    AZ-2011-201891       Cameo Clasp Envelope, with clear poly window
#
#     Discount  Sales  Profit  Quantity         Category Sub-Category
# 0        0.0     26       7         2  Office Supplies       Labels
# 1        0.0     85      15         2        Furniture  Furnishings
# 2        0.0    294     109         7       Technology  Accessories
# 3        0.0    800     168         3       Technology     Machines
# 5        0.0     76      11         3        Furniture  Furnishings
# 6        0.0    252      15         5  Office Supplies      Binders
# 7        0.0     90      17         3  Office Supplies     Supplies
# 8        0.0   1334     200         8       Technology       Phones
# 9        0.0     32       6         3  Office Supplies       Labels
# 10       0.0     88       3         2        Furniture  Furnishings
# 11       0.0    284      43         5  Office Supplies          Art
# 12       0.1    541     156         4        Furniture    Bookcases
# 13       0.0    294     109         7       Technology  Accessories
# 14       0.1    576      51         5  Office Supplies      Storage
# 15       0.0     44      14         3  Office Supplies      Binders
# 16       0.0     96      21         4  Office Supplies     Supplies
# 17       0.1    307      99         5        Furniture       Chairs
# 18       0.1    748     283         4  Office Supplies      Storage
# 19       0.0    152      44         2  Office Supplies   Appliances
# 20       0.0    957     316        12       Technology       Phones
# 22       0.0     33      10         3  Office Supplies      Binders
# 23       0.0     28      10         2  Office Supplies    Fasteners
# 26       0.0     38      11         2        Furniture  Furnishings
# 27       0.0     13       3         2  Office Supplies      Binders
# 28       0.0    800     168         3       Technology     Machines
# 29       0.1    748     283         4  Office Supplies      Storage
# 30       0.0   1908     820         3       Technology       Phones
# 31       0.0    630     132         5        Furniture    Bookcases
# 32       0.0     46       8         3  Office Supplies          Art
# 33       0.0    636     140         1       Technology       Phones
# 35       0.0     10       2         2  Office Supplies      Binders
# 36       0.0     54       8         5  Office Supplies       Labels
# 37       0.0     73      29         3  Office Supplies          Art
# 38       0.0    193      29         7  Office Supplies          Art
# 39       0.0    666      66         9       Technology  Accessories
# 41       0.0    442       0         3       Technology      Copiers
# 42       0.1    241      24         2  Office Supplies      Storage
# 46       0.0    176      65         4  Office Supplies     Supplies
# 47       0.0     94      16         5  Office Supplies    Envelopes
# 48       0.0    510     132        11  Office Supplies          Art
# 49       0.0    193      29         7  Office Supplies          Art
# 50       0.0     15       1         2  Office Supplies       Labels
# 51       0.0     39       8         3  Office Supplies       Labels
# 52       0.0    364     142         2       Technology       Phones
# 53       0.0     18       3         2  Office Supplies      Binders
# 54       0.0     10       2         2  Office Supplies      Binders
# 56       0.0    156      34         3        Furniture  Furnishings
# 57       0.0     98      12         2  Office Supplies      Binders
# 58       0.1   1667     185         6  Office Supplies   Appliances
# 0        0.0    339     102         7  Office Supplies      Binders
# 1        0.0    288      20         2        Furniture    Bookcases
# 2        0.4     61       7         6  Office Supplies      Storage
# 3        0.0     71       1         3  Office Supplies          Art
# 5        0.0    132      54         5  Office Supplies          Art
# 6        0.0     97      12         2  Office Supplies      Binders
# 7        0.0    136      15         4  Office Supplies        Paper
# 8        0.0     52      19         4  Office Supplies    Envelopes

# %%
df[df['Profit'] <= 0].index
# Out:
# Int64Index([41], dtype='int64')

# %%
#your code here
df=df.drop(df[df['Profit'] <= 0].index)

# %%
df.shape
# Out:
# (52, 8)

# %%
df4=df.loc[df.Category=='Technology']

# %%
df4
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# 52  AZ-2011-1722024            Cisco Audio Dock, VoIP       0.0    364
# 63  AZ-2011-1967754      Logitech Numeric Keypad, USB       0.0     93
#
#     Profit  Quantity    Category Sub-Category
# 2      109         7  Technology  Accessories
# 3      168         3  Technology     Machines
# 8      200         8  Technology       Phones
# 20     316        12  Technology       Phones
# 30     820         3  Technology       Phones
# 33     140         1  Technology       Phones
# 39      66         9  Technology  Accessories
# 52     142         2  Technology       Phones
# 63      40         2  Technology  Accessories

# %%
df4['Profit_per_qty']=df4['Profit']/df4['Quantity']
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2088\4212157033.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['Profit_per_qty']=df4['Profit']/df4['Quantity']

# %%
df4
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# 52  AZ-2011-1722024            Cisco Audio Dock, VoIP       0.0    364
# 63  AZ-2011-1967754      Logitech Numeric Keypad, USB       0.0     93
#
#     Profit  Quantity    Category Sub-Category  Profit_per_qty
# 2      109         7  Technology  Accessories       15.571429
# 3      168         3  Technology     Machines       56.000000
# 8      200         8  Technology       Phones       25.000000
# 20     316        12  Technology       Phones       26.333333
# 30     820         3  Technology       Phones      273.333333
# 33     140         1  Technology       Phones      140.000000
# 39      66         9  Technology  Accessories        7.333333
# 52     142         2  Technology       Phones       71.000000
# 63      40         2  Technology  Accessories       20.000000

# %%
df5=df4.sort_values(by='Profit_per_qty', ascending=True)
df5
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 13  AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 28  AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 52  AZ-2011-1722024            Cisco Audio Dock, VoIP       0.0    364
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
#
#     Profit  Quantity    Category Sub-Category  Profit_per_qty
# 39      66         9  Technology  Accessories        7.333333
# 2      109         7  Technology  Accessories       15.571429
# 13     109         7  Technology  Accessories       15.571429
# 8      200         8  Technology       Phones       25.000000
# 20     316        12  Technology       Phones       26.333333
# 3      168         3  Technology     Machines       56.000000
# 28     168         3  Technology     Machines       56.000000
# 52     142         2  Technology       Phones       71.000000
# 33     140         1  Technology       Phones      140.000000
# 30     820         3  Technology       Phones      273.333333

# %%
df5.iloc[0,:2]
# Out:
# Order ID                        AZ-2011-1536006
# Product Name    Logitech Keyboard, Programmable
# Name: 39, dtype: object

# %%
df4=df[df.Profit>0]
df4=df4.loc[df4.Category=='Technology']

df4['Profit_per_qty']=df4['Profit']/df4['Quantity']

df4.sort_values(by='Profit_per_qty',ascending=True)
# Out:
#            Order ID                      Product Name  Discount  Sales  \
# 39  AZ-2011-1536006   Logitech Keyboard, Programmable       0.0    666
# 2   AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 13  AZ-2011-1087704     Belkin Flash Drive, Bluetooth       0.0    294
# 8   AZ-2011-1174243  Nokia Audio Dock, with Caller ID       0.0   1334
# 20  AZ-2011-1322840  Motorola Headset, with Caller ID       0.0    957
# 3   AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 28  AZ-2011-1372644        Panasonic Printer, Durable       0.0    800
# 52  AZ-2011-1722024            Cisco Audio Dock, VoIP       0.0    364
# 33  AZ-2011-1445262       Apple Smart Phone, Cordless       0.0    636
# 30  AZ-2011-1410648      Nokia Smart Phone, Full Size       0.0   1908
#
#     Profit  Quantity    Category Sub-Category  Profit_per_qty
# 39      66         9  Technology  Accessories        7.333333
# 2      109         7  Technology  Accessories       15.571429
# 13     109         7  Technology  Accessories       15.571429
# 8      200         8  Technology       Phones       25.000000
# 20     316        12  Technology       Phones       26.333333
# 3      168         3  Technology     Machines       56.000000
# 28     168         3  Technology     Machines       56.000000
# 52     142         2  Technology       Phones       71.000000
# 33     140         1  Technology       Phones      140.000000
# 30     820         3  Technology       Phones      273.333333

# %%
d4=d4.loc(df.Category=='Technology')
d4['Profit_per_oty']=d4['Profit']/d4['Quantity']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19132\3396948024.py in ?()
# ----> 1 d4=d4.loc(df.Category=='Technology')
#       2 d4['Profit_per_oty']=d4['Profit']/d4['Quantity']
#
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     718         # we need to return a copy of ourselves
#     719         new_self = type(self)(self.name, self.obj)
#     720
#     721         if axis is not None:
# --> 722             axis_int_none = self.obj._get_axis_number(axis)
#     723         else:
#     724             axis_int_none = axis
#     725         new_self.axis = axis_int_none
#
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     549     @classmethod
#     550     def _get_axis_number(cls, axis: Axis) -> AxisInt:
#     551         try:
#     552             return cls._AXIS_TO_AXIS_NUMBER[axis]
# --> 553         except KeyError:
#     554             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'
